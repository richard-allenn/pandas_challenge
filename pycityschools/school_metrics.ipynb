# %%
import pandas as pd

# File to Load (Remember to Change These)
school_data = "Resources/schools_complete.csv"
student_data = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data)
student_data = pd.read_csv(student_data)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# local government area summary
# _____________________________

# %%
school_data_complete.head()
# Out:
#    Student ID     student_name gender  year        school_name  reading_score  \
# 0           0     Paul Bradley      M     9  Huang High School             96
# 1           1     Victor Smith      M    12  Huang High School             90
# 2           2  Kevin Rodriguez      M    12  Huang High School             41
# 3           3    Richard Scott      M    12  Huang High School             89
# 4           4       Bonnie Ray      F     9  Huang High School             87
#
#    maths_score  School ID        type  size   budget
# 0           94          0  Government  2917  1910635
# 1           43          0  Government  2917  1910635
# 2           76          0  Government  2917  1910635
# 3           86          0  Government  2917  1910635
# 4           69          0  Government  2917  1910635

# %%
# count number of schools
number_of_schools = len(school_data)

# %%
#count number of students
total_students = len(school_data_complete)

# %%
#calculate total budget 
total_budget = sum(school_data["budget"])

# %%
#calculate average maths score
average_maths_score = sum(student_data["maths_score"])/total_students

# %%
# average reading score
average_reading_score = sum(student_data["reading_score"])/total_students

# %%
#% of people passsing maths
passing_maths = sum(student_data["maths_score"] > 49.99)/total_students

# %%
# % of people passing reading
passing_reading = sum(student_data["reading_score"] > 49.99)/total_students

# %%
# % people passing overall
passing_overall = student_data[(student_data["reading_score"]> 49) &(student_data["maths_score"]> 49)].count()/total_students

# %%
# Local goverbnment area summary
part_1 = {"total schools":number_of_schools,"total students":total_students,"total budget":total_budget, "average maths score":average_maths_score,"average reading score": average_reading_score,"% passing maths":passing_maths,"% passing reading": passing_reading,"% passing overall": passing_overall[2]}
LGA_summary = pd.DataFrame([part_1])
LGA_summary
# Out:
#    total schools  total students  total budget  average maths score  \
# 0             15           39170      24649428            70.338192
#
#    average reading score  % passing maths  % passing reading  \
# 0              69.980138         0.860786           0.844269
#
#    % passing overall
# 0           0.728083

# %% [markdown]
# school summary
# ______________

# %%
#total budget
school_data["per student budget"] = (
school_data["budget"] / school_data["size"])

# %%
grouped_school = school_data_complete.groupby(school_data_complete["school_name"])

# %%
#average reading score


reading_averagesdf = grouped_school["reading_score"].mean()

per_school1 = pd.merge(school_data, reading_averagesdf, on="school_name")
per_school1.head()
# Out:
#    School ID            school_name         type  size   budget  \
# 0          0      Huang High School   Government  2917  1910635
# 1          1   Figueroa High School   Government  2949  1884411
# 2          2    Shelton High School  Independent  1761  1056600
# 3          3  Hernandez High School   Government  4635  3022020
# 4          4    Griffin High School  Independent  1468   917500
#
#    per student budget  reading_score
# 0               655.0      68.910525
# 1               639.0      69.077993
# 2               600.0      70.257808
# 3               652.0      69.186408
# 4               625.0      71.245232

# %%
print(grouped_school)
maths_averagesdf = grouped_school["maths_score",].mean()

per_school2 = pd.merge(per_school1, maths_averagesdf, on="school_name")
per_school2.head()
# Out:
# ...
#    School ID            school_name         type  size   budget  \
# 0          0      Huang High School   Government  2917  1910635
# 1          1   Figueroa High School   Government  2949  1884411
# 2          2    Shelton High School  Independent  1761  1056600
# 3          3  Hernandez High School   Government  4635  3022020
# 4          4    Griffin High School  Independent  1468   917500
#
#    per student budget  reading_score  maths_score
# 0               655.0      68.910525    68.935207
# 1               639.0      69.077993    68.698542
# 2               600.0      70.257808    72.034072
# 3               652.0      69.186408    68.874865
# 4               625.0      71.245232    71.788147

# %%
stu_passingmath = student_data[student_data['maths_score'] > 49.99].groupby(['school_name'])['maths_score'].count()

per_school3 = pd.merge(per_school2, stu_passingmath, on="school_name")

per_school3['% passing math'] = (per_school3['maths_score_y'] /per_school3['size'])*100

per_school3
# Out:
#     School ID            school_name         type  size   budget  \
# 0           0      Huang High School   Government  2917  1910635
# 1           1   Figueroa High School   Government  2949  1884411
# 2           2    Shelton High School  Independent  1761  1056600
# 3           3  Hernandez High School   Government  4635  3022020
# 4           4    Griffin High School  Independent  1468   917500
# 5           5     Wilson High School  Independent  2283  1319574
# 6           6    Cabrera High School  Independent  1858  1081356
# 7           7     Bailey High School   Government  4976  3124928
# 8           8     Holden High School  Independent   427   248087
# 9           9       Pena High School  Independent   962   585858
# 10         10     Wright High School  Independent  1800  1049400
# 11         11  Rodriguez High School   Government  3999  2547363
# 12         12    Johnson High School   Government  4761  3094650
# ...

# %%
#% passing raeding
stu_passingreading = student_data[student_data['reading_score'] > 49.99].groupby(['school_name'])['reading_score'].count()

per_school4 = pd.merge(per_school3, stu_passingreading, on="school_name")

per_school4['% passing reading'] = (per_school4['reading_score_y'] /per_school4['size'])*100

per_school4.head()
# Out:
#    School ID            school_name         type  size   budget  \
# 0          0      Huang High School   Government  2917  1910635
# 1          1   Figueroa High School   Government  2949  1884411
# 2          2    Shelton High School  Independent  1761  1056600
# 3          3  Hernandez High School   Government  4635  3022020
# 4          4    Griffin High School  Independent  1468   917500
#
#    per student budget  reading_score_x  maths_score_x  maths_score_y  \
# 0               655.0        68.910525      68.935207           2383
# 1               639.0        69.077993      68.698542           2408
# 2               600.0        70.257808      72.034072           1612
# 3               652.0        69.186408      68.874865           3752
# 4               625.0        71.245232      71.788147           1339
#
#    % passing math  reading_score_y  % passing reading
# 0       81.693521             2376          81.453548
# 1       81.654798             2442          82.807731
# ...

# %%
per_school4.rename(columns={'type': 'school_type', 'size': 'total_students',"budget":"school_budget", 'reading_score_x':'average reading score','maths_score_x':'average maths score'}, inplace=True)

per_school5 = per_school4.drop(["maths_score_y","reading_score_y"], axis=1)

per_school5.head()
# Out:
#    School ID            school_name  school_type  total_students  \
# 0          0      Huang High School   Government            2917
# 1          1   Figueroa High School   Government            2949
# 2          2    Shelton High School  Independent            1761
# 3          3  Hernandez High School   Government            4635
# 4          4    Griffin High School  Independent            1468
#
#    school_budget  per student budget  average reading score  \
# 0        1910635               655.0              68.910525
# 1        1884411               639.0              69.077993
# 2        1056600               600.0              70.257808
# 3        3022020               652.0              69.186408
# 4         917500               625.0              71.245232
#
#    average maths score  % passing math  % passing reading
# 0            68.935207       81.693521          81.453548
# 1            68.698542       81.654798          82.807731
# ...

# %%
passing_overall = student_data[(student_data["reading_score"]> 49) &(student_data["maths_score"]> 49)].groupby('school_name').count()

passing_overall["student_name"]
per_school6 = pd.merge(per_school5, passing_overall["student_name"], on="school_name")
passing_overall_perc = (per_school6["student_name"]/per_school6[total_students]*100)
school_summary = pd.merge(per_school5, passing_overall_perc, on=school_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\richa\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 39170
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14060\1512473522.py in <module>
# ...

# %% [markdown]
# highest performing school
# ____________________________

# %%
top_schools = per_school5.sort_values('% passing math', ascending =False).head(5)

top_schools
# Out:
#     School ID          school_name  school_type  total_students  \
# 10         10   Wright High School  Independent            1800
# 9           9     Pena High School  Independent             962
# 7           7   Bailey High School   Government            4976
# 2           2  Shelton High School  Independent            1761
# 4           4  Griffin High School  Independent            1468
#
#     school_budget  per student budget  average reading score  \
# 10        1049400               583.0              70.969444
# 9          585858               609.0              71.613306
# 7         3124928               628.0              71.008842
# 2         1056600               600.0              70.257808
# 4          917500               625.0              71.245232
#
#     average maths score  % passing math  % passing reading
# 10            72.047222       91.777778          86.666667
# 9             72.088358       91.683992          86.590437
# ...

# %% [markdown]
# lowest performing schools
# ________________________

# %%
bottom_schools = per_school5.sort_values('% passing math').head(5)

bottom_schools
# Out:
#     School ID            school_name school_type  total_students  \
# 3           3  Hernandez High School  Government            4635
# 1           1   Figueroa High School  Government            2949
# 0           0      Huang High School  Government            2917
# 12         12    Johnson High School  Government            4761
# 13         13       Ford High School  Government            2739
#
#     school_budget  per student budget  average reading score  \
# 3         3022020               652.0              69.186408
# 1         1884411               639.0              69.077993
# 0         1910635               655.0              68.910525
# 12        3094650               650.0              69.039277
# 13        1763916               644.0              69.572472
#
#     average maths score  % passing math  % passing reading
# 3             68.874865       80.949299          81.877023
# 1             68.698542       81.654798          82.807731
# ...

# %% [markdown]
# maths scores by year
# ___________________

# %%
per_school6.head()
# Out:
#    School ID            school_name  school_type  total_students  \
# 0          0      Huang High School   Government            2917
# 1          1   Figueroa High School   Government            2949
# 2          2    Shelton High School  Independent            1761
# 3          3  Hernandez High School   Government            4635
# 4          4    Griffin High School  Independent            1468
#
#    school_budget  per student budget  average reading score  \
# 0        1910635               655.0              68.910525
# 1        1884411               639.0              69.077993
# 2        1056600               600.0              70.257808
# 3        3022020               652.0              69.186408
# 4         917500               625.0              71.245232
#
#    average maths score  % passing math  % passing reading  student_name
# 0            68.935207       81.693521          81.453548          1946
# ...

# %%
# maths score averages by group

spending_maths_scores = school_data_complete.groupby(["school_name","year"])

spending_maths_scoresdf = spending_maths_scores["maths_score"].mean()

spending_maths_scoresdf.head()
# Out:
# school_name          year
# Bailey High School   9       72.493827
#                      10      71.897498
#                      11      72.374900
#                      12      72.675097
# Cabrera High School  9       72.321970
# Name: maths_score, dtype: float64

# %%
#average reading scores per group
spending_reading_scores = school_data_complete.groupby(["school_name","year"])
spending_reading_scoresdf = spending_reading_scores["reading_score"].mean()
spending_reading_scoresdf.head()
# Out:
# school_name          year
# Bailey High School   9       70.901920
#                      10      70.848265
#                      11      70.317346
#                      12      72.195525
# Cabrera High School  9       71.172348
# Name: reading_score, dtype: float64

# %%
per_school7.head()
# Out:
#    School ID            school_name  school_type  total_students  \
# 0          0      Huang High School   Government            2917
# 1          1   Figueroa High School   Government            2949
# 2          2    Shelton High School  Independent            1761
# 3          3  Hernandez High School   Government            4635
# 4          4    Griffin High School  Independent            1468
#
#    school_budget  per student budget  average reading score  \
# 0        1910635               655.0              68.910525
# 1        1884411               639.0              69.077993
# 2        1056600               600.0              70.257808
# 3        3022020               652.0              69.186408
# 4         917500               625.0              71.245232
#
#    average maths score  % passing math  % passing reading cost_group
# 0            68.935207       81.693521          81.453548   $645-680
# 1            68.698542       81.654798          82.807731   $630-645
# ...

# %%
#spending summary 
spending_bins = [0, 585, 630, 645, 680]
cut_offs = ["<$585", "$585-630", "$630-645", "$645-680"]
per_school7 = per_school5

per_school7["cost_group"] = pd.cut(per_school7["per student budget"], spending_bins, labels=cut_offs, include_lowest=True)

scores_by_spending = per_school7[["average reading score","average maths score", "% passing math", "% passing reading", "cost_group"]]

spending_summary = scores_by_spending.groupby("cost_group").mean()

# %%
spending_maths_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Maths Score"]
spending_reading_scores = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]
spending_passing_maths = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Maths"]
spending_passing_reading = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Reading"]
overall_passing_spending = school_spending_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Overall Passing"]
